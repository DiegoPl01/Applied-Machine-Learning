# %% [markdown]
# # Assignment 02
#
# Dear Team Members,
#
# I hope you are doing GREAT!
#
# The following assignment is a step-by-step process to implement a multiclass classification using Iris classical dataset.
# The idea of the current assignment is to intensify what we have learned in deep learning.
#
# There are some new concepts and challenges that we will face in the current assignment, and we need to resolve each issue and move to the next step.
#
# After the midterm, we will discuss part of the potential challenges. The assignment is easy to follow yet needs the patience to solve each question at a time.
#
# **Note:**
#
# Please note that every question has 0.5 and it provides five out of total ten marks for the assignment.
#
# The video presentation, as you have done for Assignment 01, provides the rest of the mark, which is 5.
#
# In short, 5 for coding + 5 for the video presentation = 10, but without YouTube presentation you receive no mark for the submission. In short, only submissions with YouTube link will be marked.

# %% [markdown]
# # ***Diego Plata 4581***
# # ***Assignment 02***

# %%
import pandas as pd
import numpy as np
import tensorflow
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from keras import models, layers
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation

# %%
#00 The iris.csv file (Iris dataset) is located in the Assignment folder below the current ipynb file.

# %% [markdown]
#  **Important Note:** We are NOT allowed to import the dataset from Keras. We need to upload the provided iris.csv file to colab from our Google Drive.

# %%
#00 1st, upload the iris.csv into your Google Drive (your Colab folder).

# %%
#01-a Find the path of iris.csv file, and save it in a variable called fileName.

# %%
fileName = "/content/drive/MyDrive/Assignment_02_iris.csv"

# %%
#01-b Read the content of the iris.csv file and save it in a variable, named iris.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
iris = pd.read_csv(fileName)

# %%
#01-c Show the first 5 rows of the dataframe.

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# As you see, the last column contains strings. We want to convert these strings to integers,  and we can work with them easily in our Neural Network model.
#
# setosa -> 0
#
# versicolor -> 1
#
# virginica -> 2

# %%
#2-a Please convert the last column strings to integers, as
# setosa -> 0
# versicolor -> 1
# virginica -> 2

# %%
iris["species"] = iris["species"].replace(to_replace = "setosa", value = 0)
iris["species"] = iris["species"].replace(to_replace = "versicolor", value = 1)
iris["species"] = iris["species"].replace(to_replace = "virginica", value = 2)

# %%
#2-b Now, check the first 5 elements of the iris dataset once again:

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#03-a Select the first four columns of the dataframe as the Data and call the data x.

# %%
x = iris.drop(["species"], axis = 1)

# %%
#03-b Select the last column as the label and call it y.

# %%
y = iris["species"]

# %%
#04 Now, it is the time to split the data (x) and the label (y) into training and testing segments,
#   and call them parts x_train,x_test,y_train,y_test.

# %%
#04-a Please split the data, and label into training and testing segments, while the size of test data is 20%,
#     and use random_state = 123 to make all the answers similar in the whole class.

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state= 123)

# %%
#04-b Please, check the first five rows of  x_train,x_test,y_train,y_test.

# %%
x_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 130           7.4          2.8           6.1          1.9
# 119           6.0          2.2           5.0          1.5
# 29            4.7          3.2           1.6          0.2
# 0             5.1          3.5           1.4          0.2
# 62            6.0          2.2           4.0          1.0

# %%
x_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 72            6.3          2.5           4.9          1.5
# 112           6.8          3.0           5.5          2.1
# 132           6.4          2.8           5.6          2.2
# 88            5.6          3.0           4.1          1.3
# 37            4.9          3.1           1.5          0.1

# %%
y_train.head()
# Out:
# 130    2
# 119    2
# 29     0
# 0      0
# 62     1
# Name: species, dtype: int64

# %%
y_test.head()
# Out:
# 72     1
# 112    2
# 132    2
# 88     1
# 37     0
# Name: species, dtype: int64

# %%
#04-c Check the length of the x_train and x_test. If the numbers are 120 & 30, AWESOME!
#     You are good to continue!

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
#05-a Please, convert y_train and y_test into categorical, and call them
#     one_hot_train_labels, and one_hot_test_labels, respectively.

# %%
one_hot_train_labels = to_categorical(y_train)
one_hot_test_labels = to_categorical(y_test)

# %%
#06-a Please define a sequential model that contains 3 dense layers.
#     In the first and second layers, use 100 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3 as the number of output,
#     and the reason is we have three classes (setosa -> 0, versicolor -> 1, virginica -> 2)
#     Also, please pick an appropriate activation function for the last layer.
#     (You already have guessed what could be the best when we have converted the labels to categorical.)

# %%
model_1 = keras.Sequential([
    keras.layers.Dense(100, input_shape = (4,), activation = "relu"),
    keras.layers.Dense(100, activation = "relu"),
    keras.layers.Dense(3, activation = "softmax")
])

# %%
#06-b Now, please compile your model using 'rmsprop', an appropriate loss function, and 'accuracy' for your metrics.

# %%
model_1.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
#07-a Pleease fit your model using epoch=20, batch = 10.

# %%
model_1.fit(x_train, one_hot_train_labels, epochs = 20, batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 3ms/step - loss: 0.8424 - accuracy: 0.6333
# Epoch 2/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.6116 - accuracy: 0.7833
# Epoch 3/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5678 - accuracy: 0.7417
# Epoch 4/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4719 - accuracy: 0.8500
# Epoch 5/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4635 - accuracy: 0.7583
# Epoch 6/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8500
# Epoch 7/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8500
# Epoch 8/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3314 - accuracy: 0.8833
# Epoch 9/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.9167
# Epoch 10/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3124 - accuracy: 0.8500
# Epoch 11/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9250
# Epoch 12/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9750
# Epoch 13/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2174 - accuracy: 0.9333
# Epoch 14/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1998 - accuracy: 0.9583
# Epoch 15/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1834 - accuracy: 0.9500
# Epoch 16/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.9417
# Epoch 17/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9417
# Epoch 18/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.9750
# Epoch 19/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1523 - accuracy: 0.9750
# Epoch 20/20
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9750

# %%
#08-a Please calculate the result, evaluating your x_test, one_hot_test_label, and see how accurate your model works.

# %%
model_1.evaluate(x_test, one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 204ms/step - loss: 0.1726 - accuracy: 0.9000
# [0.1725882589817047, 0.8999999761581421]

# %%
#09-a Now, we repeate all we have done in #06-a with the following parameters:
#     In the first and second layers, use 10 hidden units (neurons) and a 'relu' activation function.
#     For the last layer, we need to use 3.

# %%
model_2 = keras.Sequential([
    keras.layers.Dense(10, input_shape = (4,), activation = "relu"),
    keras.layers.Dense(10, activation = "relu"),
    keras.layers.Dense(3, activation = "Softmax")
])

# %%
#09-b Use the same setting as you have done for #06-b (compile phase using 'rmsprom' and et cetera)

# %%
model_2.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
#09-c Please fit your model using epoch=4, batch = 10.

# %%
model_2.fit(x_train, one_hot_train_labels, epochs = 4, batch_size = 10)
# Out:
# Epoch 1/4
# 12/12 [==============================] - 1s 2ms/step - loss: 1.1614 - accuracy: 0.4750
# Epoch 2/4
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0853 - accuracy: 0.4917
# Epoch 3/4
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0405 - accuracy: 0.4750
# Epoch 4/4
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0036 - accuracy: 0.6417

# %%
#09-d Please calculate the result, evaluating your x_test, one_hot_test_label, and see how accurate your model works.

# %%
model_2.evaluate(x_test, one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 146ms/step - loss: 1.0017 - accuracy: 0.6000
# [1.0016834735870361, 0.6000000238418579]

# %%
#10-a Please explain all you have learned from this assignment.
# Theese are some quiestions that you could answer:
# How the number of layers or hidden units could impact the accuracy of our model.
# Do we always suffer from overfitting?
# How can we find and manage overfitting?

# %% [markdown]
# Double-click here to start typing your answer: when the number of layers and hidden units in a layer increase, the accuracy of the model increases too. When we train the model for lower number of training datasets, less epochs we will face the overfitting issue but it doesn't happen always. When overfitting happens the accuracy for the train data is high but accuracy for the validation data is very low compared with the train data accuracy. We can eliminate the overfitting by trainning the model using high amount of training data sets, using the dropout layers

# %%
#10-b
# Please try different sessing as we did in #09
# You can change the number of layers, hidden units, compile parameters, number of epochs, batch_size... everything!
# Please change one parameter at a time.
# And share your experience.

# %% [markdown]
# # Sessing 01

# %%
model_3 = keras.Sequential([
    keras.layers.Dense(500, input_shape = (4,), activation = "relu"),
    keras.layers.Dense(200, activation = "relu"),
    keras.layers.Dense(150, activation = "relu"),
    keras.layers.Dense(3, activation = "softmax")
])

# %%
model_3.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
model_3.fit(x_train, one_hot_train_labels, epochs = 20, batch_size = 10)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 1s 4ms/step - loss: 0.8560 - accuracy: 0.5250
# Epoch 2/20
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5166 - accuracy: 0.7583
# Epoch 3/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3304 - accuracy: 0.8583
# Epoch 4/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3540 - accuracy: 0.8583
# Epoch 5/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3201 - accuracy: 0.9000
# Epoch 6/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1992 - accuracy: 0.9333
# Epoch 7/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2636 - accuracy: 0.9000
# Epoch 8/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1858 - accuracy: 0.9250
# Epoch 9/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1348 - accuracy: 0.9500
# Epoch 10/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2705 - accuracy: 0.8750
# Epoch 11/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1021 - accuracy: 0.9833
# Epoch 12/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2799 - accuracy: 0.8750
# Epoch 13/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.9333
# Epoch 14/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9000
# Epoch 15/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1425 - accuracy: 0.9417
# Epoch 16/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.9667
# Epoch 17/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9750
# Epoch 18/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9417
# Epoch 19/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1042 - accuracy: 0.9667
# Epoch 20/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2501 - accuracy: 0.9333

# %%
model_3.evaluate(x_test, one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 160ms/step - loss: 0.1314 - accuracy: 0.9667
# [0.1313922107219696, 0.9666666388511658]

# %% [markdown]
# From experimenting with **sessing 01**, when we **increase** the number of hidden layers, the accuracy **increases** for validation data.

# %% [markdown]
# # Sessing 02

# %%
model_4 = keras.Sequential([
    keras.layers.Dense(500, input_shape = (4,), activation = "relu"),
    keras.layers.Dense(200, activation = "relu"),
    keras.layers.Dense(150, activation = "relu"),
    keras.layers.Dense(3, activation = "softmax")
])

# %%
model_4.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
model_4.fit(x_train, one_hot_train_labels, epochs = 20, batch_size = 2)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 1s 5ms/step - loss: 0.6682 - accuracy: 0.7250
# Epoch 2/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.3614 - accuracy: 0.8167
# Epoch 3/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2875 - accuracy: 0.8333
# Epoch 4/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.2554 - accuracy: 0.9333
# Epoch 5/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1703 - accuracy: 0.9333
# Epoch 6/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1482 - accuracy: 0.9750
# Epoch 7/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.2157 - accuracy: 0.9417
# Epoch 8/20
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1819 - accuracy: 0.9250
# Epoch 9/20
# 60/60 [==============================] - 1s 10ms/step - loss: 0.1613 - accuracy: 0.9333
# Epoch 10/20
# 60/60 [==============================] - 1s 8ms/step - loss: 0.1076 - accuracy: 0.9500
# Epoch 11/20
# 60/60 [==============================] - 1s 10ms/step - loss: 0.2160 - accuracy: 0.9333
# Epoch 12/20
# 60/60 [==============================] - 0s 8ms/step - loss: 0.2020 - accuracy: 0.9250
# Epoch 13/20
# 60/60 [==============================] - 1s 8ms/step - loss: 0.1117 - accuracy: 0.9750
# Epoch 14/20
# 60/60 [==============================] - 1s 11ms/step - loss: 0.1488 - accuracy: 0.9250
# Epoch 15/20
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0970 - accuracy: 0.9667
# Epoch 16/20
# 60/60 [==============================] - 1s 8ms/step - loss: 0.1999 - accuracy: 0.9333
# Epoch 17/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1233 - accuracy: 0.9500
# Epoch 18/20
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1203 - accuracy: 0.9667
# Epoch 19/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9917
# Epoch 20/20
# 60/60 [==============================] - 0s 3ms/step - loss: 0.1427 - accuracy: 0.9583

# %%
model_4.evaluate(x_test, one_hot_test_labels)
# Out:
# 1/1 [==============================] - 0s 148ms/step - loss: 0.1110 - accuracy: 0.9667
# [0.1109534204006195, 0.9666666388511658]

# %% [markdown]
# From experimenting with **sessing 02**, when we **reduce** the hatch size, the accuracy **increases** for the validation data.

# %% [markdown]
# # Sessing 03

# %%
model_5 = keras.Sequential([
    keras.layers.Dense(500, input_shape = (4,), activation = "relu"),
    keras.layers.Dense(200, activation = "relu"),
    keras.layers.Dense(150, activation = "relu"),
    keras.layers.Dense(3, activation = "softmax")
])

# %%
model_5.compile(
    optimizer = "rmsprop",
    loss = "categorical_crossentropy",
    metrics = ["accuracy"]
)

# %%
model_5.fit(x_train, one_hot_train_labels, epochs = 5, batch_size = 10)
# Out:
# Epoch 1/5
# 12/12 [==============================] - 1s 4ms/step - loss: 0.8344 - accuracy: 0.5667
# Epoch 2/5
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4386 - accuracy: 0.7750
# Epoch 3/5
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3476 - accuracy: 0.8417
# Epoch 4/5
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3531 - accuracy: 0.8417
# Epoch 5/5
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2744 - accuracy: 0.8833

# %%
model_5.evaluate(x_test, one_hot_test_labels)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x7a7a79136200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 157ms/step - loss: 0.3548 - accuracy: 0.7667
# [0.3547535538673401, 0.7666666507720947]

# %% [markdown]
# From experimenting with **sessing 03**, when we **reduce** the number of epochs, the accuracy **reduces** for the test data (or validation data).

# %% [markdown]
# ---
# # Deliverables:
# 1. Please, submit the current ipynb file with your responses.
# 2. Please record and upload to YouTube a 5 to 10 minutes video recorded clip, describing all you have done. If you go beyond 10 minutes, it is fine. The mentioned time range is to show how the scale of the assignment could be.
#
# Notes:
# - In your submission, YOU MUST SUBMIT A LINK TO YOUR YOUTUBE VIDEO as a COMENTS SUBMISSION SECTION on your D2L SUBMISSION. Omitting this comment will result in a 0% for your total mark.
#
# - To get the 5% of the (coding) mark, you need to submit a YouTube video that scrolls through your code, explaining every single line of your code.
#
# Then submit the link to the uploaded YouTube video in the **Comments Submision section**.

# %% [markdown]
# **Summary:**
#
# In short, what we need to submit are:
#
# a)	The current **ipynb file** that contains all the code (5 marks).
#
# b)	The **YouTube link** of your recorded video in the
# **Comments Submission section** (5 marks).
#
# Zero for submissions, without YouTube video explanation.

# %% [markdown]
# Wish you only the best, Dear Team Members!
#
# Reza

# %%
https://youtu.be/PQ904Bn4SJY
